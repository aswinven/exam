# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\admin\Downloads\diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
y=data['Outcome']

# %%
data.replace(0,np.nan,inplace=True)

# %%
data.isna().sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
plt.hist(data['Pregnancies'])
plt.show()

# %%
plt.hist(data['Glucose'])
plt.show()

# %%
plt.hist(data['BloodPressure'])
plt.show()

# %%
plt.hist(data['SkinThickness'])
plt.show()

# %%
plt.hist(data['Insulin'])
plt.show()

# %%
plt.hist(data['BMI'])
plt.show()

# %%
plt.hist(data['Outcome'])
plt.show()

# %%
data['Pregnancies']=data['Pregnancies'].fillna(data['Pregnancies'].median())
data['Glucose']=data['Glucose'].fillna(data['Glucose'].mean())
data['BloodPressure']=data['BloodPressure'].fillna(data['BloodPressure'].mean())
data['SkinThickness']=data['SkinThickness'].fillna(data['SkinThickness'].median())
data['Insulin']=data['Insulin'].fillna(data['Insulin'].median())
data['BMI']=data['BMI'].fillna(data['BMI'].median())

# %%
data.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
plt.boxplot(data['Pregnancies'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2259265c0d0>,
#   <matplotlib.lines.Line2D at 0x2259265c3a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2259265c670>,
#   <matplotlib.lines.Line2D at 0x2259265c940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22592647dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2259265cc10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2259265cee0>],
#  'means': []}

# %%
plt.boxplot(data['Glucose'])
plt.show()

# %%
plt.boxplot(data['BloodPressure'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22592733670>,
#   <matplotlib.lines.Line2D at 0x22592733940>],
#  'caps': [<matplotlib.lines.Line2D at 0x22592733c10>,
#   <matplotlib.lines.Line2D at 0x22592733ee0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x225927333a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x225927401f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x225927404c0>],
#  'means': []}

# %%
plt.boxplot(data['SkinThickness'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2259375fa30>,
#   <matplotlib.lines.Line2D at 0x2259375fd00>],
#  'caps': [<matplotlib.lines.Line2D at 0x2259375ffd0>,
#   <matplotlib.lines.Line2D at 0x225937702e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2259375f760>],
#  'medians': [<matplotlib.lines.Line2D at 0x225937705b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22593770880>],
#  'means': []}

# %%
plt.boxplot(data['Insulin'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22593785820>,
#   <matplotlib.lines.Line2D at 0x22593785af0>],
#  'caps': [<matplotlib.lines.Line2D at 0x22593785dc0>,
#   <matplotlib.lines.Line2D at 0x225937950d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22593785550>],
#  'medians': [<matplotlib.lines.Line2D at 0x225937953a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22593795670>],
#  'means': []}

# %%
plt.boxplot(data['BMI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x225937ea670>,
#   <matplotlib.lines.Line2D at 0x225937ea940>],
#  'caps': [<matplotlib.lines.Line2D at 0x225937eac10>,
#   <matplotlib.lines.Line2D at 0x225937eaee0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x225937ea3a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x225937f81f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x225937f84c0>],
#  'means': []}

# %%
plt.boxplot(data['DiabetesPedigreeFunction'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2259269e2b0>,
#   <matplotlib.lines.Line2D at 0x225926ba250>],
#  'caps': [<matplotlib.lines.Line2D at 0x225926ba2b0>,
#   <matplotlib.lines.Line2D at 0x225926ba970>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2259269e5b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x225926ba3a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x225926ba6d0>],
#  'means': []}

# %%
plt.boxplot(data['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2259252d3d0>,
#   <matplotlib.lines.Line2D at 0x2259252d370>],
#  'caps': [<matplotlib.lines.Line2D at 0x2259252dfa0>,
#   <matplotlib.lines.Line2D at 0x22592526b50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2259252d760>],
#  'medians': [<matplotlib.lines.Line2D at 0x22592526970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22592526310>],
#  'means': []}

# %%
data=data.drop(['Outcome'],axis=1)

# %%
x=data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0    125.0  33.6
# 1          1.0     85.0           66.0           29.0    125.0  26.6
# 2          8.0    183.0           64.0           29.0    125.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          4.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # logisticRegrssion

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
log_ac=accuracy_score(y_test,y_pred)

# %%
log_ac
# Out:
# 0.7792207792207793

# %% [markdown]
# # confusiom matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[84, 15],
#        [19, 36]], dtype=int64)

# %% [markdown]
# # knn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
m=[]
n=np.arange(3,15)
for K in n:
    clf=KNeighborsClassifier(n_neighbors=K)
    clf.fit(x_train,y_train)
    pred=clf.predict(x_test)
    acc=accuracy_score(y_test,pred)
    m.append(acc)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
plt.plot(n,m,'o-')
plt.xlabel('K values')
plt.ylabel('accuracy')
plt.grid()

# %%
clf=KNeighborsClassifier(n_neighbors=9)
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred_knn=clf.predict(x_test)
acc_knn=accuracy_score(y_test,y_pred_knn)
print(acc_knn)
# Out:
# 0.6818181818181818
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# # svc

# %%
from sklearn.svm import SVC
sv=SVC()

# %%
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred_sv=sv.predict(x_test)

# %%
accuracy_score(y_test,y_pred_sv)
# Out:
# 0.7597402597402597

# %% [markdown]
# # decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt=dt.predict(x_test)

# %%
dt_ac=accuracy_score(y_test,y_pred_dt)

# %%
dt_ac
# Out:
# 0.7207792207792207

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.7662337662337663

# %% [markdown]
# # precision score

# %%
from sklearn.metrics import precision_score

# %%
pr=precision_score(y_test,y_pred)

# %%
pr
# Out:
# 0.7058823529411765
